# %%
import numpy as np
import seaborn
import matplotlib.pyplot as plt

# %%
ss1 = np.load('./result1/testerror3.npy')

# %%
plt.plot(np.linspace(0,1,len(ss1[0:,0])),ss1[0:,0])

# %%
seaborn.heatmap(ss.T,vmin = 0,vmax = 0.8,cmap = 'YlGnBu')
# Out:
# <AxesSubplot:>

# %%
sss = np.load('./result/trainingerror2.npy')
sss[np.isnan(sss)] = 0

# %%
ax = seaborn.heatmap(sss.T,vmin = 0,vmax = 0.15,cmap = 'YlGnBu')
ax.invert_yaxis()

# %%
ssss = np.load('./result/testerror2.npy')
ssss[np.isnan(ssss)] = 0.05
ax = seaborn.heatmap(ssss.T,vmin = 0,vmax = 0.25,cmap = 'YlGnBu')
ax.invert_yaxis()

# %%
# ?np.random.randn
